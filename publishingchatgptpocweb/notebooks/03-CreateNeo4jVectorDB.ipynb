# %%
import os
import openai
import requests
import re
from pathlib import Path
from dotenv import load_dotenv
load_dotenv()

from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.llms import OpenAI
from langchain.chat_models import ChatOpenAI
from langchain.chains import GraphCypherQAChain
from langchain.graphs import Neo4jGraph
from langchain.document_loaders import TextLoader
from neo4j import GraphDatabase
from langchain.vectorstores import Neo4jVector

# %%
PARENT_PATH = Path.cwd().parent
if 'publishingchatgptpocweb' not in str(PARENT_PATH):
    PARENT_PATH = PARENT_PATH / 'publishingchatgptpocweb'

DATA_DIRECTORY = PARENT_PATH / 'data'

JATS_DATA_DIRECTORY_PATH = DATA_DIRECTORY / 'raw'
ARTICLES_DATA_DIRECTORY_PATH = DATA_DIRECTORY / 'processed' / 'articles'
CONCEPTS_DATA_DIRECTORY_PATH = DATA_DIRECTORY / 'processed' / 'concepts'

# %%
OPEN_AI_API_SECRET = os.getenv('Open__AI__API__Secret')
openai.api_key = OPEN_AI_API_SECRET

# %%
def update_article_metadata(document):
    # Extracting various details from the page_content
    title_match = re.search(r'Title:\s*(.*?)(?:\n|$)', document.page_content)
    pan_match = re.search(r'PAN:\s*(.*?)(?:\n|$)', document.page_content)
    source_match = re.search(r'Article Link/URL/Source:\s*(.*?)(?:\n|$)', document.page_content)
    pub_date = re.search(r'Publishing Date:\s*(.*?)(?:\n|$)', document.page_content)    
    isbn_match = re.search(r'ISBN:\s*(.*?)(?:\n|$)', document.page_content)
    day_match = re.search(r'Day:\s*(\d{1,2})(?:\n|$)', document.page_content)
    month_match = re.search(r'Month:\s*(\d{1,2})(?:\n|$)', document.page_content)
    year_match = re.search(r'Year:\s*(\d{4})(?:\n|$)', document.page_content)

    document.metadata['document_type'] = 'article'
    # Updating metadata dictionary
    if title_match:
        document.metadata['title'] = title_match.group(1)
    if pan_match:
        document.metadata['pan'] = pan_match.group(1)
    if source_match:
        document.metadata['source'] = source_match.group(1)
    if isbn_match:
        document.metadata['isbn'] = isbn_match.group(1)
    if day_match and month_match and year_match:
        pub_date = f"{year_match.group(1)}-{month_match.group(1).zfill(2)}-{day_match.group(1).zfill(2)}"
        document.metadata['publishing_date'] = pub_date   
    
    return document

def update_concepts_metadata(document):
    # Extracting various details from the page_content
    document.metadata['document_type'] = 'concept'
    concept_section = re.search(r'Thesaurus Concept:\n\s*Concept:\n(.*?)\n(?:\s*Broader Concept:|\s*Narrower Concepts:|\s*Related Concepts:|\Z)', document.page_content, re.DOTALL)
    if concept_section:
        concept_details = concept_section.group(1)
        name_match = re.search(r'name:\s*(.*?)(?:\n|$)', concept_details)
        uri_match = re.search(r'uri:\s*(.*?)(?:\n|$)', concept_details)
        # Updating metadata dictionary
        if name_match:
            document.metadata['name'] = name_match.group(1)
            document.metadata['title'] = name_match.group(1)
        if uri_match:
            document.metadata['uri'] = uri_match.group(1)
            document.metadata['source'] = uri_match.group(1)        
    return document    



def add_document_to_neo4j_vector_db(existing_index, data_directory, type='article'):
    for root_dir, sub_dirs, files in os.walk(data_directory):
        for file_name in files:
            if file_name.endswith('.txt'):
                try:
                    text_file_path = os.path.join(root_dir, file_name)
                    loader = TextLoader(text_file_path, encoding='utf8')
                    documents = loader.load()
                    if type=='articles':
                        documents[0] = update_article_metadata(documents[0])
                    elif type=='concepts':
                        documents[0] = update_concepts_metadata(documents[0])
                    existing_index.add_documents(documents)
                except:
                    print('error adding document', file_name)
    return existing_index

def create_vector_data_from_processed_documents():   
    loader = TextLoader(os.path.join(JATS_DATA_DIRECTORY_PATH, 'test.txt'))
    documents = loader.load()
    neo4j_db = Neo4jVector.from_documents(
        documents,
        embeddings,
        url=os.getenv('Local__Neo4J__URL'),
        username=os.getenv('Local__Neo4J__UserName'),
        password=os.getenv('Local__Neo4J__Password'),
        database=os.getenv('Local__Neo4J__Database'),
        index_name=os.getenv('Local__Neo4J__PrimaryIndexName'),
        node_label="PublishingDataChunk",  # Chunk by default
        text_node_property="info",  # text by default
        embedding_node_property="vector",  # embedding by default
        create_id_index=True,  # True by default
        pre_delete_collection=False # False by default
    )
        
    existing_index = Neo4jVector.from_existing_index(
        embeddings,
        url=os.getenv('Local__Neo4J__URL'),
        username=os.getenv('Local__Neo4J__UserName'),
        password=os.getenv('Local__Neo4J__Password'),
        database=os.getenv('Local__Neo4J__Database'),
        index_name=os.getenv('Local__Neo4J__PrimaryIndexName'),
        text_node_property="info",
    )
    existing_index = add_document_to_neo4j_vector_db(existing_index, ARTICLES_DATA_DIRECTORY_PATH, 'articles')
    existing_index = add_document_to_neo4j_vector_db(existing_index, CONCEPTS_DATA_DIRECTORY_PATH, 'concepts')






def create_relationships_in_neo4j_db():
    driver = GraphDatabase.driver(neo4j_url, auth=(neo4j_username, neo4j_password))    

    with driver.session(database=neo4j_database) as session:
        all_articles_nodes = session.execute_read(get_nodes,'article')
        all_concept_nodes = session.execute_read(get_nodes,'concept')

        # Creating a mapping of concept names to nodes for efficient lookup
        concept_name_to_node = {node['n'].get('name'): node['n'] for node in all_concept_nodes if node['n'].get('name')}

        # Mapping of vocab type to relationship name
        vocab_type_to_relationship_name = {
            'preferred_terms': 'HAS_PREFERRED_TERM',
            'organism_terms': 'HAS_ORGANISM_TERM',
            'geographic_terms': 'HAS_GEOGRAPHIC_TERM',
        }
        
        # # Step 2: Create Article to Concept relationships
        # for article_node in all_articles_nodes:
        #     article_node= article_node['n']
        #     article_content = article_node['info']
            
        #     vocab_sections = extract_vocab_sections_from_article_content(article_content)
           
        #     for vocab_type, concepts in vocab_sections.items():
        #         relationship_name = vocab_type_to_relationship_name.get(vocab_type)
        #         for concept_name in concepts:
        #             concept_node = concept_name_to_node.get(concept_name)
        #             if concept_node and relationship_name:                    
        #                 try:
        #                     session.execute_write(create_article_concept_relationship, article_node, concept_node, relationship_name)
        #                     print(article_node['pan'], relationship_name, concept_node['name'], 'DONE')                        
        #                 except:
        #                     print(article_node['pan'], relationship_name, concept_node['name'], 'ERROR')        
        #     # if article_node['n']['pan']=='20203180098':
        #     #     break
        
        #     print()
        #     print('---------------')
        #     print()
    
    
        # Step 3: Create Concept to Concept relationships
        for concept_node in all_concept_nodes:
            concept_details = concept_node['n']['info']  # Adjust field name based on your data structure
            concept_node= concept_node['n']
            if 'name' not in concept_node:
                continue
            
            # Identify broader, narrower, and related concepts using regex
            broader_concept_section = re.search(r'Broader Concept:\s*\n*\s*name: (.*?)(?:\n|, uri)', concept_details)
            if broader_concept_section:
                broader_concepts = [broader_concept_section.group(1)]
            else:
                broader_concepts = []
            
            narrower_concept_section = re.search(r'Narrower Concepts:([\s\S]*?)(?:Broader Concepts:|Related Concepts:|$)', concept_details)
            if narrower_concept_section:
                narrower_concepts = re.findall(r'name: (.*?)(?:, uri|\n|$)', narrower_concept_section.group(1))
            else:
                narrower_concepts = []
            
            related_concept_section = re.search(r'Related Concepts:([\s\S]*?)(?:Broader Concepts:|Narrower Concepts:|$)', concept_details)
            if related_concept_section:
                related_concepts = re.findall(r'name: (.*?)(?:, uri|\n|$)', related_concept_section.group(1))
            else:
                related_concepts = []
             
            # Create relationships with other concept nodes based on broader, narrower, and related concepts
            for broader_concept_name in broader_concepts:
                broader_concept_node = concept_name_to_node.get(broader_concept_name)
                if broader_concept_node:
                    try:
                        session.execute_write(create_concept_relationship, broader_concept_node, concept_node, 'BROADER_TERM_FOR')
                        print(broader_concept_node['name'], 'BROADER_TERM_FOR', concept_node['name'], 'DONE')                    
                    except Exception as e:
                        print(broader_concept_node['name'], 'BROADER_TERM_FOR', concept_node['name'], 'ERROR')  
                        print(e)
                       
        
            for narrower_concept_name in narrower_concepts:
                narrower_concept_node = concept_name_to_node.get(narrower_concept_name)
                if narrower_concept_node:
                    try:
                        session.execute_write(create_concept_relationship, narrower_concept_node, concept_node, 'NARROWER_TERM_FOR')
                        print(narrower_concept_node['name'], 'NARROWER_TERM_FOR', concept_node['name'], 'DONE')                    
                    except Exception as e:
                        print(narrower_concept_node['name'], 'NARROWER_TERM_FOR', concept_node['name'], 'ERROR')
                        print(e)
                       
        
            for related_concept_name in related_concepts:
                related_concept_node = concept_name_to_node.get(related_concept_name)
                if related_concept_node:
                    try:
                        session.execute_write(create_concept_relationship, related_concept_node, concept_node, 'RELATED_TERM')
                        print(related_concept_node['name'], 'RELATED_TERM', concept_node['name'], 'DONE')                    
                    except Exception as e:                
                        print(related_concept_node['name'], 'RELATED_TERM', concept_node['name'], 'ERROR')
                        print(e)
                        
        
            print()
            print('---------------')
            print()


def get_nodes(tx, document_type):
        return tx.run(f"MATCH (n) WHERE n.document_type = '{document_type}' RETURN n", database=neo4j_database).data()

def create_article_concept_relationship(tx, start_node, end_node, relationship_type):
    query = f"""
    MATCH (a {{pan: '{start_node['pan']}'}})
    MATCH (b {{name: '{end_node['name']}'}})
    MERGE (a)-[r:{relationship_type}]->(b)
    """
    tx.run(query, database=neo4j_database)

def create_concept_relationship(tx, start_node, end_node, relationship_type):
    query = f"""
    MATCH (a {{name: '{start_node['name']}'}})
    MATCH (b {{name: '{end_node['name']}'}})
    MERGE (a)-[r:{relationship_type}]->(b)
    """
    tx.run(query, database=neo4j_database)

   
def extract_vocab_sections_from_article_content(article_content):
    vocab_sections = {
        'preferred_terms': [],
        'organism_terms': [],
        'geographic_terms': [],
    }
    
    # Define patterns for each section
    patterns = {
        'preferred_terms': r'Preferred Terms \(Non-geographic, Non-organism contents from thesaurus\):\s*\n(.*?)(?:\s*(?:Organism Terms|Geographic Terms|$))',
        'organism_terms': r'Organism Terms \(Organism names from thesaurus\):\s*\n(.*?)(?:\s*(?:Preferred Terms|Geographic Terms|$))',
        'geographic_terms': r'Geographic Terms \(Geographic Tags indicating content about a place\):\s*\n(.*?)(?:\s*\n{2,}|$)',
    }

    # Extract terms for each section
    for section, pattern in patterns.items():
        match = re.search(pattern, article_content, re.DOTALL)
        if match:
            vocab_sections[section] = [term.lstrip('- ').strip() for term in match.group(1).split('\n') if term.strip()]

    return vocab_sections

# %%
# create_vector_data_from_processed_documents()
create_relationships_in_neo4j_db()
# Out:
# ---------------
#
#
# ---------------
#
# buildings BROADER_TERM_FOR abattoirs DONE
# slaughter RELATED_TERM abattoirs DONE
# meat production RELATED_TERM abattoirs DONE
# meat hygiene RELATED_TERM abattoirs DONE
#
# ---------------
#
# cattle BROADER_TERM_FOR Aberdeen-Angus DONE
#
# ---------------
#
# stomach BROADER_TERM_FOR abomasum DONE
#
# ---------------
#
# reproductive disorders BROADER_TERM_FOR abortion DONE
# reproduction RELATED_TERM abortion DONE
# infertility RELATED_TERM abortion DONE
# fetal death RELATED_TERM abortion DONE
# brucellosis RELATED_TERM abortion DONE
# birth RELATED_TERM abortion DONE
#
# ---------------
#
# optical properties BROADER_TERM_FOR absorbance DONE
#
# ---------------
#
# sorption BROADER_TERM_FOR absorption DONE
# adsorption RELATED_TERM absorption DONE
# uptake RELATED_TERM absorption DONE
# nutrient uptake RELATED_TERM absorption DONE
# desorption RELATED_TERM absorption DONE
#
# ---------------
#
# pesticides BROADER_TERM_FOR acaricides DONE
# ectoparasiticides RELATED_TERM acaricides DONE
# tick control RELATED_TERM acaricides DONE
#
# ---------------
#
# characteristics BROADER_TERM_FOR acceptability DONE
#
# ---------------
#
#
# ---------------
#
# health hazards BROADER_TERM_FOR accidents DONE
# falls NARROWER_TERM_FOR accidents DONE
# traffic accidents NARROWER_TERM_FOR accidents DONE
# accident prevention RELATED_TERM accidents DONE
# first aid RELATED_TERM accidents DONE
# safety RELATED_TERM accidents DONE
# safety at work RELATED_TERM accidents DONE
#
# ---------------
#
# prevention BROADER_TERM_FOR accident prevention DONE
# accidents RELATED_TERM accident prevention DONE
# safety RELATED_TERM accident prevention DONE
#
# ---------------
#
# climate RELATED_TERM acclimatization DONE
# adaptation RELATED_TERM acclimatization DONE
# resistance RELATED_TERM acclimatization DONE
# physiology RELATED_TERM acclimatization DONE
#
# ---------------
#
# tourism RELATED_TERM accommodation DONE
#
# ---------------
#
#
# ---------------
#
# turnover RELATED_TERM accounting DONE
# budgets RELATED_TERM accounting DONE
# finance RELATED_TERM accounting DONE
#
# ---------------
#
#
# ---------------
#
# characteristics BROADER_TERM_FOR accuracy DONE
# measurement RELATED_TERM accuracy DONE
#
# ---------------
#
#
# ---------------
#
#
# ---------------
#
#
# ---------------
#
# vinegar RELATED_TERM acetic acid DONE
#
# ---------------
#
#
# ---------------
#
# choline RELATED_TERM acetylcholine DONE
# nervous system RELATED_TERM acetylcholine DONE
#
# ---------------
#
# acids RELATED_TERM acidification DONE
# chemistry RELATED_TERM acidification DONE
# processing RELATED_TERM acidification DONE
# pH RELATED_TERM acidification DONE
# acidity RELATED_TERM acidification DONE
#
# ---------------
#
# alkalinity NARROWER_TERM_FOR acidity DONE
# titratable acidity NARROWER_TERM_FOR acidity DONE
# pH NARROWER_TERM_FOR acidity DONE
# acids RELATED_TERM acidity DONE
# flavour RELATED_TERM acidity DONE
# chemistry RELATED_TERM acidity DONE
# acidification RELATED_TERM acidity DONE
#
# ---------------
#
# Bacteria BROADER_TERM_FOR Acidobacteria DONE
#
# ---------------
#
# organic acids NARROWER_TERM_FOR acids DONE
# chemistry RELATED_TERM acids DONE
# acidification RELATED_TERM acids DONE
# acidity RELATED_TERM acids DONE
#
# ---------------
#
# phosphoric monoester hydrolases BROADER_TERM_FOR acid phosphatase DONE
#
# ---------------
#
# skin diseases BROADER_TERM_FOR acne DONE
#
# ---------------
#
#
# ---------------
#
# physics BROADER_TERM_FOR acoustics DONE
# hearing RELATED_TERM acoustics DONE
#
# ---------------
#
# immunological deficiency BROADER_TERM_FOR acquired immune deficiency syndrome DONE
# immunocompromised hosts RELATED_TERM acquired immune deficiency syndrome DONE
#
# ---------------
#
#
# ---------------
#
# globulins BROADER_TERM_FOR actin DONE
#
# ---------------
#
#
# ---------------
#
# Bacteria BROADER_TERM_FOR Actinobacteria DONE
#
# ---------------
#
# antibiotics RELATED_TERM Actinomyces DONE
#
# ---------------
#
#
# ---------------
#
# charcoal RELATED_TERM activated carbon DONE
# filters RELATED_TERM activated carbon DONE
# carbon RELATED_TERM activated carbon DONE
#
# ---------------
#
# sewage sludge BROADER_TERM_FOR activated sludge DONE
#
# ---------------
#
# infections BROADER_TERM_FOR acute infections DONE
#
# ---------------
#
# blood proteins BROADER_TERM_FOR acute phase proteins DONE
# C-reactive protein NARROWER_TERM_FOR acute phase proteins DONE
#
# ---------------
#
#
# ---------------
#
# mutations RELATED_TERM adaptation DONE
# climate RELATED_TERM adaptation DONE
# environmental factors RELATED_TERM adaptation DONE
# acclimatization RELATED_TERM adaptation DONE
# physiology RELATED_TERM adaptation DONE
# altitude RELATED_TERM adaptation DONE
# climatic factors RELATED_TERM adaptation DONE
#
# ---------------
#
# behaviour disorders BROADER_TERM_FOR addiction DONE
# alcoholism RELATED_TERM addiction DONE
#
# ---------------
#
# carcinoma BROADER_TERM_FOR adenocarcinoma DONE
#
# ---------------
#
#
# ---------------
#
# ATP RELATED_TERM adenosinetriphosphatase DONE
#
# ---------------
#
# obesity RELATED_TERM adipose tissue DONE
#
# ---------------
#
# immunostimulants RELATED_TERM adjuvants DONE
# chemistry RELATED_TERM adjuvants DONE
# pesticides RELATED_TERM adjuvants DONE
#
# ---------------
#
# regionalization NARROWER_TERM_FOR administration DONE
# decentralization NARROWER_TERM_FOR administration DONE
# management RELATED_TERM administration DONE
# social sciences RELATED_TERM administration DONE
# governance RELATED_TERM administration DONE
# planning RELATED_TERM administration DONE
# government RELATED_TERM administration DONE
#
# ---------------
#
# oral administration NARROWER_TERM_FOR administration routes DONE
# drug delivery systems RELATED_TERM administration routes DONE
#
# ---------------
#
# young adults RELATED_TERM adolescents DONE
# adults RELATED_TERM adolescents DONE
# children RELATED_TERM adolescents DONE
# school children RELATED_TERM adolescents DONE
# youth RELATED_TERM adolescents DONE
#
# ---------------
#
# chemistry RELATED_TERM adsorbents DONE
# adsorption RELATED_TERM adsorbents DONE
#
# ---------------
#
# sorption BROADER_TERM_FOR adsorption DONE
# absorption RELATED_TERM adsorption DONE
# adsorbents RELATED_TERM adsorption DONE
# desorption RELATED_TERM adsorption DONE
#
# ---------------
#
# contamination RELATED_TERM adulteration DONE
#
# ---------------
#
# developmental stages BROADER_TERM_FOR adults DONE
# young adults NARROWER_TERM_FOR adults DONE
# adolescents RELATED_TERM adults DONE
# age groups RELATED_TERM adults DONE
#
# ---------------
#
# toxicity RELATED_TERM adverse effects DONE
# nontarget effects RELATED_TERM adverse effects DONE
#
# ---------------
#
# sales promotion RELATED_TERM advertising DONE
#
# ---------------
#
#
# ---------------
#
# processing BROADER_TERM_FOR aeration DONE
#
# ---------------
#
#
# ---------------
#
#
# ---------------
#
# smoke NARROWER_TERM_FOR aerosols DONE
# particulate matter RELATED_TERM aerosols DONE
#
# ---------------
#
# disease transmission RELATED_TERM aetiology DONE
# disease distribution RELATED_TERM aetiology DONE
# mixed infections RELATED_TERM aetiology DONE
# epidemiology RELATED_TERM aetiology DONE
# pathogenicity RELATED_TERM aetiology DONE
# plant diseases RELATED_TERM aetiology DONE
# spread RELATED_TERM aetiology DONE
#
# ---------------
#
# forestry practices RELATED_TERM afforestation DONE
# forestry RELATED_TERM afforestation DONE
# soil conservation RELATED_TERM afforestation DONE
#
# ---------------
#
# Central Asia BROADER_TERM_FOR Afghanistan DONE
#
# ---------------
#
#
# ---------------
#
# mycotoxins BROADER_TERM_FOR aflatoxins DONE
#
# ---------------
#
# Africa South of Sahara NARROWER_TERM_FOR Africa DONE
#
# ---------------
#
# ethnic groups BROADER_TERM_FOR African Americans DONE
#
# ---------------
#
# tick-borne diseases BROADER_TERM_FOR African horse sickness DONE
#
# ---------------
#
#
# ---------------
#
# swine diseases BROADER_TERM_FOR African swine fever DONE
#
# ---------------
#
#
# ---------------
#
# Africa BROADER_TERM_FOR Africa South of Sahara DONE
# West Africa NARROWER_TERM_FOR Africa South of Sahara DONE
# Central Africa NARROWER_TERM_FOR Africa South of Sahara DONE
# East Africa NARROWER_TERM_FOR Africa South of Sahara DONE
#
# ---------------
#
#
# ---------------
#
#
# ---------------
#
# properties BROADER_TERM_FOR age DONE
# age differences RELATED_TERM age DONE
# age groups RELATED_TERM age DONE
# stand age RELATED_TERM age DONE
# aging RELATED_TERM age DONE
#
# ---------------
#
# age RELATED_TERM age differences DONE
# population structure RELATED_TERM age differences DONE
# aging RELATED_TERM age differences DONE
#
# ---------------
#
# groups BROADER_TERM_FOR age groups DONE
# adults RELATED_TERM age groups DONE
# age RELATED_TERM age groups DONE
#
# ---------------
#
# immunity RELATED_TERM agglutination DONE
# immune response RELATED_TERM agglutination DONE
#
# ---------------
#
#
# ---------------
#
#
# ---------------
#
# bullying NARROWER_TERM_FOR aggressive behaviour DONE
# terrorism RELATED_TERM aggressive behaviour DONE
#
# ---------------
#
# biological development BROADER_TERM_FOR aging DONE
# ripening RELATED_TERM aging DONE
# senescence RELATED_TERM aging DONE
# age RELATED_TERM aging DONE
# age differences RELATED_TERM aging DONE
#
# ---------------
#
# chemicals BROADER_TERM_FOR agricultural chemicals DONE
# farm inputs RELATED_TERM agricultural chemicals DONE
# chemistry RELATED_TERM agricultural chemicals DONE
# formulations RELATED_TERM agricultural chemicals DONE
# chemoprophylaxis RELATED_TERM agricultural chemicals DONE
#
# ---------------
#
# credit BROADER_TERM_FOR agricultural credit DONE
# support measures RELATED_TERM agricultural credit DONE
#
# ---------------
#
# development BROADER_TERM_FOR agricultural development DONE
# modernization RELATED_TERM agricultural development DONE
# rural development RELATED_TERM agricultural development DONE
# economic development RELATED_TERM agricultural development DONE
# development policy RELATED_TERM agricultural development DONE
# agricultural situation RELATED_TERM agricultural development DONE
#
# ---------------
#
# education BROADER_TERM_FOR agricultural education DONE
# curriculum RELATED_TERM agricultural education DONE
# science education RELATED_TERM agricultural education DONE
#
# ---------------
#
# engineering BROADER_TERM_FOR agricultural engineering DONE
# farm machinery RELATED_TERM agricultural engineering DONE
# agriculture RELATED_TERM agricultural engineering DONE
# mechanization RELATED_TERM agricultural engineering DONE
# agricultural machinery industry RELATED_TERM agricultural engineering DONE
# technical progress RELATED_TERM agricultural engineering DONE
#
# ---------------
#
# households RELATED_TERM agricultural households DONE
#
# ---------------
#
# deforestation RELATED_TERM agricultural land DONE
# land use RELATED_TERM agricultural land DONE
# farms RELATED_TERM agricultural land DONE
#
# ---------------
#
# agricultural engineering RELATED_TERM agricultural machinery industry DONE
# equipment RELATED_TERM agricultural machinery industry DONE
# farm machinery RELATED_TERM agricultural machinery industry DONE
#
# ---------------
#
# meteorology BROADER_TERM_FOR agricultural meteorology DONE
# climate RELATED_TERM agricultural meteorology DONE
# meteorological factors RELATED_TERM agricultural meteorology DONE
# climatic factors RELATED_TERM agricultural meteorology DONE
#
# ---------------
#
# agricultural policy RELATED_TERM agricultural planning DONE
#
# ---------------
#
# policy BROADER_TERM_FOR agricultural policy DONE
# CAP NARROWER_TERM_FOR agricultural policy DONE
# agricultural planning RELATED_TERM agricultural policy DONE
# food policy RELATED_TERM agricultural policy DONE
# trade policy RELATED_TERM agricultural policy DONE
# economic policy RELATED_TERM agricultural policy DONE
# forest policy RELATED_TERM agricultural policy DONE
# agricultural situation RELATED_TERM agricultural policy DONE
# support measures RELATED_TERM agricultural policy DONE
#
# ---------------
#
# farming RELATED_TERM agricultural production DONE
# horticulture RELATED_TERM agricultural production DONE
# agricultural situation RELATED_TERM agricultural production DONE
#
# ---------------
#
# animal products RELATED_TERM agricultural products DONE
# plant products RELATED_TERM agricultural products DONE
# commodities RELATED_TERM agricultural products DONE
#
# ---------------
#
# research BROADER_TERM_FOR agricultural research DONE
# agriculture RELATED_TERM agricultural research DONE
#
# ---------------
#
# industry BROADER_TERM_FOR agricultural sector DONE
#
# ---------------
#
# agricultural development RELATED_TERM agricultural situation DONE
# agricultural production RELATED_TERM agricultural situation DONE
# agricultural policy RELATED_TERM agricultural situation DONE
#
# ---------------
#
#
# ---------------
#
# trade BROADER_TERM_FOR agricultural trade DONE
# commodities RELATED_TERM agricultural trade DONE
#
# ---------------
#
# wastes BROADER_TERM_FOR agricultural wastes DONE
# animal wastes RELATED_TERM agricultural wastes DONE
# crop residues RELATED_TERM agricultural wastes DONE
#
# ---------------
#
# urban agriculture NARROWER_TERM_FOR agriculture DONE
# agricultural research RELATED_TERM agriculture DONE
# agronomy RELATED_TERM agriculture DONE
# plantations RELATED_TERM agriculture DONE
# food production RELATED_TERM agriculture DONE
# pastures RELATED_TERM agriculture DONE
# farms RELATED_TERM agriculture DONE
# horticulture RELATED_TERM agriculture DONE
# farming systems RELATED_TERM agriculture DONE
# estates RELATED_TERM agriculture DONE
# farming RELATED_TERM agriculture DONE
# animal husbandry RELATED_TERM agriculture DONE
# crop production RELATED_TERM agriculture DONE
# forestry RELATED_TERM agriculture DONE
# agricultural engineering RELATED_TERM agriculture DONE
# fields RELATED_TERM agriculture DONE
#
# ---------------
#
#
# ---------------
#
# forestry BROADER_TERM_FOR agroforestry DONE
# land use RELATED_TERM agroforestry DONE
# community forestry RELATED_TERM agroforestry DONE
# sustainability RELATED_TERM agroforestry DONE
# intercropping RELATED_TERM agroforestry DONE
# agroforestry systems RELATED_TERM agroforestry DONE
#
# ---------------
#
# farming systems BROADER_TERM_FOR agroforestry systems DONE
# silvicultural systems RELATED_TERM agroforestry systems DONE
# agroforestry RELATED_TERM agroforestry systems DONE
#
# ---------------
#
# industry BROADER_TERM_FOR agroindustrial sector DONE
# food industry RELATED_TERM agroindustrial sector DONE
# economic sectors RELATED_TERM agroindustrial sector DONE
#
# ---------------
#
# genotypes RELATED_TERM agronomic characteristics DONE
# characteristics RELATED_TERM agronomic characteristics DONE
#
# ---------------
#
# agriculture RELATED_TERM agronomy DONE
#
# ---------------
#
# farming systems BROADER_TERM_FOR agropastoral systems DONE
# pastoralism RELATED_TERM agropastoral systems DONE
# pastoral society RELATED_TERM agropastoral systems DONE
#
# ---------------
#
#
# ---------------
#
# air pollution RELATED_TERM air DONE
# air flow RELATED_TERM air DONE
# atmosphere RELATED_TERM air DONE
# air pollutants RELATED_TERM air DONE
# air transport RELATED_TERM air DONE
# air temperature RELATED_TERM air DONE
# air microbiology RELATED_TERM air DONE
#
# ---------------
#
# air RELATED_TERM air flow DONE
# fans RELATED_TERM air flow DONE
#
# ---------------
#
# microbial flora RELATED_TERM air microbiology DONE
# air RELATED_TERM air microbiology DONE
#
# ---------------
#
# pollutants BROADER_TERM_FOR air pollutants DONE
# greenhouse gases NARROWER_TERM_FOR air pollutants DONE
# particulate matter NARROWER_TERM_FOR air pollutants DONE
# air RELATED_TERM air pollutants DONE
# emissions RELATED_TERM air pollutants DONE
# pollution RELATED_TERM air pollutants DONE
# air pollution RELATED_TERM air pollutants DONE
#
# ---------------
#
# pollution BROADER_TERM_FOR air pollution DONE
# indoor air pollution NARROWER_TERM_FOR air pollution DONE
# air RELATED_TERM air pollution DONE
# air pollutants RELATED_TERM air pollution DONE
#
# ---------------
#
# environmental temperature BROADER_TERM_FOR air temperature DONE
# solar radiation RELATED_TERM air temperature DONE
# air RELATED_TERM air temperature DONE
#
# ---------------
#
# transport BROADER_TERM_FOR air transport DONE
# air RELATED_TERM air transport DONE
#
# ---------------
#
#
# ---------------
#
#
# ---------------
#
#
# ---------------
#
# proteins BROADER_TERM_FOR albumins DONE
#
# ---------------
#
#
# ---------------
#
# beverages BROADER_TERM_FOR alcoholic beverages DONE
# wines NARROWER_TERM_FOR alcoholic beverages DONE
# beers NARROWER_TERM_FOR alcoholic beverages DONE
# alcohol intake RELATED_TERM alcoholic beverages DONE
# molasses RELATED_TERM alcoholic beverages DONE
# alcoholism RELATED_TERM alcoholic beverages DONE
#
# ---------------
#
# human diseases BROADER_TERM_FOR alcoholism DONE
# alcoholic beverages RELATED_TERM alcoholism DONE
# addiction RELATED_TERM alcoholism DONE
#
# ---------------
#
# intake BROADER_TERM_FOR alcohol intake DONE
# alcoholic beverages RELATED_TERM alcohol intake DONE
#
# ---------------
#
#
# ---------------
#
# Alexandrium minutum NARROWER_TERM_FOR Alexandrium DONE
# Alexandrium catenella NARROWER_TERM_FOR Alexandrium DONE
# algal blooms RELATED_TERM Alexandrium DONE
#
# ---------------
#
# Alexandrium BROADER_TERM_FOR Alexandrium catenella DONE
#
# ---------------
#
# Alexandrium BROADER_TERM_FOR Alexandrium minutum DONE
#
# ---------------
#
# plants BROADER_TERM_FOR algae DONE
# Chlorophyta NARROWER_TERM_FOR algae DONE
# algicides RELATED_TERM algae DONE
# aquatic plants RELATED_TERM algae DONE
# seaweeds RELATED_TERM algae DONE
# algal blooms RELATED_TERM algae DONE
#
# ---------------
#
# Alexandrium RELATED_TERM algal blooms DONE
# paralytic shellfish toxins RELATED_TERM algal blooms DONE
# eutrophication RELATED_TERM algal blooms DONE
# Cyanobacteria RELATED_TERM algal blooms DONE
# algae RELATED_TERM algal blooms DONE
#
# ---------------
#
#
# ---------------
#
# herbicides BROADER_TERM_FOR algicides DONE
# algae RELATED_TERM algicides DONE
#
# ---------------
#
# mathematics RELATED_TERM algorithms DONE
#
# ---------------
#
#
# ---------------
#
# phosphoric monoester hydrolases BROADER_TERM_FOR alkaline phosphatase DONE
#
# ---------------
#
# acidity BROADER_TERM_FOR alkalinity DONE
#
# ---------------
#
# genes BROADER_TERM_FOR alleles DONE
#
# ---------------
#
# semiochemicals BROADER_TERM_FOR allelochemicals DONE
#
# ---------------
#
# toxicity RELATED_TERM allelopathy DONE
#
# ---------------
#
# antigens BROADER_TERM_FOR allergens DONE
# skin tests RELATED_TERM allergens DONE
# allergies RELATED_TERM allergens DONE
#
# ---------------
#
# arthropod allergies NARROWER_TERM_FOR allergies DONE
# food allergies NARROWER_TERM_FOR allergies DONE
# immune sensitization RELATED_TERM allergies DONE
# allergens RELATED_TERM allergies DONE
# immunity RELATED_TERM allergies DONE
# anaphylaxis RELATED_TERM allergies DONE
# immune response RELATED_TERM allergies DONE
#
# ---------------
#
# botanical insecticides BROADER_TERM_FOR allicin DONE
#
# ---------------
#
# Allium sativum NARROWER_TERM_FOR Allium DONE
# Allium cepa NARROWER_TERM_FOR Allium DONE
#
# ---------------
#
# Allium BROADER_TERM_FOR Allium cepa DONE
# Allium cepa var. aggregatum NARROWER_TERM_FOR Allium cepa DONE
#
# ---------------
#
# Allium cepa BROADER_TERM_FOR Allium cepa var. aggregatum DONE
#
# ---------------
#
# Allium BROADER_TERM_FOR Allium sativum DONE
#
# ---------------
#
#
# ---------------
#
#
# ---------------
#
# amylases BROADER_TERM_FOR alpha-amylase DONE
#
# ---------------
#
#
# ---------------
#
# essential oils RELATED_TERM alpha-pinene DONE
#
# ---------------
#
# Potexvirus NARROWER_TERM_FOR Alphaflexiviridae DONE
#
# ---------------
#
# Proteobacteria BROADER_TERM_FOR Alphaproteobacteria DONE
#
# ---------------
#
#
# ---------------
#
#
# ---------------
#
# hosts BROADER_TERM_FOR alternative hosts DONE
#
# ---------------
#
# geography RELATED_TERM altitude DONE
# topography RELATED_TERM altitude DONE
# adaptation RELATED_TERM altitude DONE
# height RELATED_TERM altitude DONE
#
# ---------------
#
# aluminium hydroxide RELATED_TERM aluminium DONE
#
# ---------------
#
# hydroxides BROADER_TERM_FOR aluminium hydroxide DONE
# aluminium RELATED_TERM aluminium hydroxide DONE
#
# ---------------
#
# Alysiella crassa NARROWER_TERM_FOR Alysiella DONE
#
# ---------------
#
# Alysiella BROADER_TERM_FOR Alysiella crassa DONE
#
# ---------------
#
# brain diseases BROADER_TERM_FOR Alzheimer's disease ERROR
# {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input 's': expected
#   "!="
#   "%"
#   "*"
#   "+"
#   ","
#   "-"
#   "/"
#   "::"
#   "<"
#   "<="
#   "<>"
#   "="
#   "=~"
#   ">"
#   ">="
#   "AND"
#   "CONTAINS"
#   "ENDS"
#   "IN"
#   "IS"
#   "OR"
#   "STARTS"
#   "XOR"
#   "^"
#   "}" (line 3, column 36 (offset: 71))
# "    MATCH (b {name: 'Alzheimer's disease'})"
#                                 ^}
# amyloid beta RELATED_TERM Alzheimer's disease ERROR
# {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input 's': expected
#   "!="
#   "%"
#   "*"
#   "+"
#   ","
#   "-"
#   "/"
#   "::"
#   "<"
#   "<="
#   "<>"
#   "="
#   "=~"
#   ">"
#   ">="
#   "AND"
#   "CONTAINS"
#   "ENDS"
#   "IN"
#   "IS"
#   "OR"
#   "STARTS"
#   "XOR"
#   "^"
#   "}" (line 3, column 36 (offset: 69))
# "    MATCH (b {name: 'Alzheimer's disease'})"
#                                 ^}
#
# ---------------
#
# greenspace NARROWER_TERM_FOR amenity and recreation areas DONE
# playgrounds NARROWER_TERM_FOR amenity and recreation areas DONE
# parks NARROWER_TERM_FOR amenity and recreation areas DONE
# tourist attractions RELATED_TERM amenity and recreation areas DONE
#
# ---------------
#
# trees BROADER_TERM_FOR amenity trees DONE
# street trees NARROWER_TERM_FOR amenity trees DONE
# greenspace RELATED_TERM amenity trees DONE
#
# ---------------
#
# Caribbean NARROWER_TERM_FOR America DONE
# Latin America NARROWER_TERM_FOR America DONE
# South America NARROWER_TERM_FOR America DONE
# North America NARROWER_TERM_FOR America DONE
#
# ---------------
#
# aminoglycoside antibiotics BROADER_TERM_FOR amikacin DONE
#
# ---------------
#
# amikacin NARROWER_TERM_FOR aminoglycoside antibiotics DONE
#
# ---------------
#
# proteins RELATED_TERM amino acids DONE
# amino acid sequences RELATED_TERM amino acids DONE
# biochemistry RELATED_TERM amino acids DONE
#
# ---------------
#
# molecular genetics RELATED_TERM amino acid sequences DONE
# amino acids RELATED_TERM amino acid sequences DONE
# peptides RELATED_TERM amino acid sequences DONE
#
# ---------------
#
#
# ---------------
#
# ammonium nitrogen RELATED_TERM ammonia DONE
# nitrification RELATED_TERM ammonia DONE
# nitrogen RELATED_TERM ammonia DONE
#
# ---------------
#
# cations BROADER_TERM_FOR ammonium DONE
#
# ---------------
#
# nitrogen fertilizers RELATED_TERM ammonium nitrogen DONE
# nitrogen RELATED_TERM ammonium nitrogen DONE
# ammonia RELATED_TERM ammonium nitrogen DONE
#
# ---------------
#
# protozoal infections BROADER_TERM_FOR amoebiasis DONE
#
# ---------------
#
#
# ---------------
#
# Closteroviridae BROADER_TERM_FOR Ampelovirus DONE
# Plum bark necrosis stem pitting-associated virus NARROWER_TERM_FOR Ampelovirus DONE
#
# ---------------
#
# vertebrates BROADER_TERM_FOR Amphibia DONE
# aquatic animals RELATED_TERM Amphibia DONE
#
# ---------------
#
# penicillins BROADER_TERM_FOR ampicillin DONE
#
# ---------------
#
# genetic markers RELATED_TERM amplified fragment length polymorphism DONE
# polymerase chain reaction RELATED_TERM amplified fragment length polymorphism DONE
#
# ---------------
#
#
# ---------------
#
# alpha-amylase NARROWER_TERM_FOR amylases DONE
# starch RELATED_TERM amylases DONE
#
# ---------------
#
# Alzheimer's disease RELATED_TERM amyloid beta ERROR
# {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input 's': expected
#   "!="
#   "%"
#   "*"
#   "+"
#   ","
#   "-"
#   "/"
#   "::"
#   "<"
#   "<="
#   "<>"
#   "="
#   "=~"
#   ">"
#   ">="
#   "AND"
#   "CONTAINS"
#   "ENDS"
#   "IN"
#   "IS"
#   "OR"
#   "STARTS"
#   "XOR"
#   "^"
#   "}" (line 2, column 28 (offset: 32))
# "    MATCH (a {name: 'Alzheimer's disease'})"
#                                 ^}
#
# ---------------
#
#
# ---------------
#
# haemolytic anaemia NARROWER_TERM_FOR anaemia DONE
# erythrocytes RELATED_TERM anaemia DONE
# haemoglobin RELATED_TERM anaemia DONE
#
# ---------------
#
# nitrogen cycle BROADER_TERM_FOR anaerobic ammonium oxidation DONE
# waste treatment RELATED_TERM anaerobic ammonium oxidation DONE
# anaerobic treatment RELATED_TERM anaerobic ammonium oxidation DONE
#
# ---------------
#
# treatment BROADER_TERM_FOR anaerobic treatment DONE
# anaerobic ammonium oxidation RELATED_TERM anaerobic treatment DONE
# methane production RELATED_TERM anaerobic treatment DONE
# waste treatment RELATED_TERM anaerobic treatment DONE
# slurries RELATED_TERM anaerobic treatment DONE
#
# ---------------
#
# Chloroflexi (phylum) BROADER_TERM_FOR Anaerolineae DONE
#
# ---------------
#
# anaesthetics RELATED_TERM anaesthesia DONE
# surgical operations RELATED_TERM anaesthesia DONE
# health protection RELATED_TERM anaesthesia DONE
#
# ---------------
#
# injectable anaesthetics NARROWER_TERM_FOR anaesthetics DONE
# anaesthesia RELATED_TERM anaesthetics DONE
#
# ---------------
#
# acetaminophen NARROWER_TERM_FOR analgesics DONE
# detomidine NARROWER_TERM_FOR analgesics DONE
# fentanyl NARROWER_TERM_FOR analgesics DONE
# butorphanol RELATED_TERM analgesics DONE
# pain RELATED_TERM analgesics DONE
#
# ---------------
#
# spectral analysis NARROWER_TERM_FOR analysis DONE
# sensitivity analysis NARROWER_TERM_FOR analysis DONE
# quantitative analysis NARROWER_TERM_FOR analysis DONE
# thermal analysis NARROWER_TERM_FOR analysis DONE
# statistical analysis NARROWER_TERM_FOR analysis DONE
# economic analysis NARROWER_TERM_FOR analysis DONE
# water analysis NARROWER_TERM_FOR analysis DONE
# genetic analysis NARROWER_TERM_FOR analysis DONE
# image analysis NARROWER_TERM_FOR analysis DONE
# analytical methods RELATED_TERM analysis DONE
# detection RELATED_TERM analysis DONE
# determination RELATED_TERM analysis DONE
# methodology RELATED_TERM analysis DONE
#
# ---------------
#
# techniques BROADER_TERM_FOR analytical methods DONE
# voltammetry NARROWER_TERM_FOR analytical methods DONE
# spectroscopy NARROWER_TERM_FOR analytical methods DONE
# microscopy NARROWER_TERM_FOR analytical methods DONE
# electrophoresis NARROWER_TERM_FOR analytical methods DONE
# analysis RELATED_TERM analytical methods DONE
#
# ---------------
#
#
# ---------------
#
#
# ---------------
#
# allergies RELATED_TERM anaphylaxis DONE
#
# ---------------
#
# plant anatomy NARROWER_TERM_FOR anatomy DONE
# histology RELATED_TERM anatomy DONE
# biology RELATED_TERM anatomy DONE
# morphology RELATED_TERM anatomy DONE
#
# ---------------
#
#
# ---------------
#
# aquaculture RELATED_TERM ancillary enterprises DONE
# handicrafts RELATED_TERM ancillary enterprises DONE
# diversification RELATED_TERM ancillary enterprises DONE
# non-farm income RELATED_TERM ancillary enterprises DONE
#
# ---------------
#
# India BROADER_TERM_FOR Andaman and Nicobar Islands DONE
#
# ---------------
#
#
# ---------------
#
# monocotyledons NARROWER_TERM_FOR angiosperms DONE
#
# ---------------
#
#
# ---------------
#
# zoogeography RELATED_TERM animals DONE
# zoology RELATED_TERM animals DONE
# fauna RELATED_TERM animals DONE
#
# ---------------
#
# behaviour BROADER_TERM_FOR animal behaviour DONE
# psychology RELATED_TERM animal behaviour DONE
# animal welfare RELATED_TERM animal behaviour DONE
# animal housing RELATED_TERM animal behaviour DONE
# orientation RELATED_TERM animal behaviour DONE
#
# ---------------
#
# horse breeding NARROWER_TERM_FOR animal breeding DONE
# animal husbandry RELATED_TERM animal breeding DONE
# embryo transfer RELATED_TERM animal breeding DONE
# breeding season RELATED_TERM animal breeding DONE
# breeding value RELATED_TERM animal breeding DONE
# breeds RELATED_TERM animal breeding DONE
#
# ---------------
#
#
# ---------------
#
# fish diseases NARROWER_TERM_FOR animal diseases DONE
# mink diseases NARROWER_TERM_FOR animal diseases DONE
# dog diseases NARROWER_TERM_FOR animal diseases DONE
# horse diseases NARROWER_TERM_FOR animal diseases DONE
# zoonoses NARROWER_TERM_FOR animal diseases DONE
# swine diseases NARROWER_TERM_FOR animal diseases DONE
# systemic diseases RELATED_TERM animal diseases DONE
#
# ---------------
#
# ecology BROADER_TERM_FOR animal ecology DONE
#
# ---------------
#
# feeding BROADER_TERM_FOR animal feeding DONE
# fish feeding NARROWER_TERM_FOR animal feeding DONE
# poultry feeding NARROWER_TERM_FOR animal feeding DONE
# animal husbandry RELATED_TERM animal feeding DONE
# feeds RELATED_TERM animal feeding DONE
#
# ---------------
#
# health BROADER_TERM_FOR animal health DONE
# animal welfare RELATED_TERM animal health DONE
# animal husbandry RELATED_TERM animal health DONE
#
# ---------------
#
# buildings BROADER_TERM_FOR animal hospitals DONE
#
# ---------------
#
# aquaria NARROWER_TERM_FOR animal housing DONE
# pig housing NARROWER_TERM_FOR animal housing DONE
# animal husbandry RELATED_TERM animal housing DONE
# animal behaviour RELATED_TERM animal housing DONE
#
# ---------------
#
# animal production BROADER_TERM_FOR animal husbandry DONE
# animal welfare RELATED_TERM animal husbandry DONE
# livestock farming RELATED_TERM animal husbandry DONE
# incubation RELATED_TERM animal husbandry DONE
# livestock RELATED_TERM animal husbandry DONE
# artificial insemination RELATED_TERM animal husbandry DONE
# farming RELATED_TERM animal husbandry DONE
# slaughter RELATED_TERM animal husbandry DONE
# agriculture RELATED_TERM animal husbandry DONE
# embryo transfer RELATED_TERM animal husbandry DONE
# beekeeping RELATED_TERM animal husbandry DONE
# sterilization RELATED_TERM animal husbandry DONE
# animal housing RELATED_TERM animal husbandry DONE
# animal health RELATED_TERM animal husbandry DONE
# animal breeding RELATED_TERM animal husbandry DONE
# destruction of animals RELATED_TERM animal husbandry DONE
# animal feeding RELATED_TERM animal husbandry DONE
#
# ---------------
#
# manures BROADER_TERM_FOR animal manures DONE
# poultry manure NARROWER_TERM_FOR animal manures DONE
# animal wastes RELATED_TERM animal manures DONE
#
# ---------------
#
# models BROADER_TERM_FOR animal models DONE
# disease models RELATED_TERM animal models DONE
#
# ---------------
#
# feeding RELATED_TERM animal nutrition DONE
# nutrition RELATED_TERM animal nutrition DONE
# feeds RELATED_TERM animal nutrition DONE
# fodder plants RELATED_TERM animal nutrition DONE
#
# ---------------
#
# parasites BROADER_TERM_FOR animal parasitic nematodes DONE
# entomophilic nematodes NARROWER_TERM_FOR animal parasitic nematodes DONE
# helminths RELATED_TERM animal parasitic nematodes DONE
# anthelmintics RELATED_TERM animal parasitic nematodes DONE
#
# ---------------
#
# physiology BROADER_TERM_FOR animal physiology DONE
#
# ---------------
#
# animal husbandry NARROWER_TERM_FOR animal production DONE
# flocks NARROWER_TERM_FOR animal production DONE
# herds NARROWER_TERM_FOR animal production DONE
# fish production NARROWER_TERM_FOR animal production DONE
# egg production RELATED_TERM animal production DONE
# meat production RELATED_TERM animal production DONE
# performance RELATED_TERM animal production DONE
# milk production RELATED_TERM animal production DONE
# performance traits RELATED_TERM animal production DONE
# wool production RELATED_TERM animal production DONE
#
# ---------------
#
# carcasses NARROWER_TERM_FOR animal products DONE
# sponges NARROWER_TERM_FOR animal products DONE
# meat NARROWER_TERM_FOR animal products DONE
# meat products NARROWER_TERM_FOR animal products DONE
# frozen semen NARROWER_TERM_FOR animal products DONE
# fish NARROWER_TERM_FOR animal products DONE
# hive products NARROWER_TERM_FOR animal products DONE
# fish products NARROWER_TERM_FOR animal products DONE
# insects as food NARROWER_TERM_FOR animal products DONE
# milk products NARROWER_TERM_FOR animal products DONE
# livestock RELATED_TERM animal products DONE
# agricultural products RELATED_TERM animal products DONE
#
# ---------------
#
#
# ---------------
#
# sport BROADER_TERM_FOR animal sports DONE
# horse riding NARROWER_TERM_FOR animal sports DONE
# horse racing NARROWER_TERM_FOR animal sports DONE
# hunting NARROWER_TERM_FOR animal sports DONE
#
# ---------------
#
# insect viruses NARROWER_TERM_FOR animal viruses DONE
#
# ---------------
#
# wastes BROADER_TERM_FOR animal wastes DONE
# agricultural wastes RELATED_TERM animal wastes DONE
# slurries RELATED_TERM animal wastes DONE
# animal manures RELATED_TERM animal wastes DONE
#
# ---------------
#
# animal husbandry RELATED_TERM animal welfare DONE
# animal behaviour RELATED_TERM animal welfare DONE
# animal health RELATED_TERM animal welfare DONE
#
# ---------------
#
# ion exchange BROADER_TERM_FOR anion exchange DONE
#
# ---------------
#
#
# ---------------
#
#
# ---------------
#
# antiparasitic agents BROADER_TERM_FOR anthelmintics DONE
# abamectin NARROWER_TERM_FOR anthelmintics DONE
# nicotine NARROWER_TERM_FOR anthelmintics DONE
# animal parasitic nematodes RELATED_TERM anthelmintics DONE
#
# ---------------
#
# flavonoids BROADER_TERM_FOR anthocyanidins DONE
# anthocyanins RELATED_TERM anthocyanidins DONE
#
# ---------------
#
# anthocyanidins RELATED_TERM anthocyanins DONE
#
# ---------------
#
#
# ---------------
#
#
# ---------------
#
# bacterial diseases BROADER_TERM_FOR anthrax DONE
#
# ---------------
#
# antiinfective agents BROADER_TERM_FOR antibacterial agents DONE
# tylosin NARROWER_TERM_FOR antibacterial agents DONE
# sulfamethoxazole NARROWER_TERM_FOR antibacterial agents DONE
# antibiotics RELATED_TERM antibacterial agents DONE
# antibacterial properties RELATED_TERM antibacterial agents DONE
#
# ---------------
#
# antimicrobial properties BROADER_TERM_FOR antibacterial properties DONE
# antibacterial agents RELATED_TERM antibacterial properties DONE
# bacterial diseases RELATED_TERM antibacterial properties DONE
# Bacteria RELATED_TERM antibacterial properties DONE
#
# ---------------
#
# aminoglycoside antibiotics NARROWER_TERM_FOR antibiotics DONE
# doxorubicin NARROWER_TERM_FOR antibiotics DONE
# bacteriocins NARROWER_TERM_FOR antibiotics DONE
# macrolide antibiotics NARROWER_TERM_FOR antibiotics DONE
# beta-lactam antibiotics NARROWER_TERM_FOR antibiotics DONE
# tetracyclines NARROWER_TERM_FOR antibiotics DONE
# antibacterial agents RELATED_TERM antibiotics DONE
# antiinfective agents RELATED_TERM antibiotics DONE
# feed additives RELATED_TERM antibiotics DONE
# chemistry RELATED_TERM antibiotics DONE
# secondary metabolites RELATED_TERM antibiotics DONE
# antibiotic residues RELATED_TERM antibiotics DONE
# Actinomyces RELATED_TERM antibiotics DONE
# mycotoxins RELATED_TERM antibiotics DONE
#
# ---------------
#
# antibiotics RELATED_TERM antibiotic residues DONE
# drug residues RELATED_TERM antibiotic residues DONE
#
# ---------------
#
# drug resistance BROADER_TERM_FOR antibiotic resistance DONE
#
# ---------------
#
# immunoglobulins BROADER_TERM_FOR antibodies DONE
# monoclonal antibodies NARROWER_TERM_FOR antibodies DONE
# antibody formation RELATED_TERM antibodies DONE
# vaccines RELATED_TERM antibodies DONE
# immunity RELATED_TERM antibodies DONE
# antigens RELATED_TERM antibodies DONE
# immune response RELATED_TERM antibodies DONE
# antibody testing RELATED_TERM antibodies DONE
#
# ---------------
#
# immune response BROADER_TERM_FOR antibody formation DONE
# antigens RELATED_TERM antibody formation DONE
# antibodies RELATED_TERM antibody formation DONE
#
# ---------------
#
# antibodies RELATED_TERM antibody testing DONE
#
# ---------------
#
# medicinal properties BROADER_TERM_FOR anticancer properties DONE
# antineoplastic properties NARROWER_TERM_FOR anticancer properties DONE
# neoplasms RELATED_TERM anticancer properties DONE
# antineoplastic agents RELATED_TERM anticancer properties DONE
# carcinogenesis RELATED_TERM anticancer properties DONE
#
# ---------------
#
# antiinfective agents BROADER_TERM_FOR antifungal agents DONE
# malachite green NARROWER_TERM_FOR antifungal agents DONE
# fungicides RELATED_TERM antifungal agents DONE
# antifungal properties RELATED_TERM antifungal agents DONE
#
# ---------------
#
# antimicrobial properties BROADER_TERM_FOR antifungal properties DONE
# antifungal agents RELATED_TERM antifungal properties DONE
# fungal diseases RELATED_TERM antifungal properties DONE
# fungicides RELATED_TERM antifungal properties DONE
# mycoses RELATED_TERM antifungal properties DONE
# fungi RELATED_TERM antifungal properties DONE
#
# ---------------
#
# immunological factors BROADER_TERM_FOR antigens DONE
# allergens NARROWER_TERM_FOR antigens DONE
# viral antigens NARROWER_TERM_FOR antigens DONE
# surface antigens NARROWER_TERM_FOR antigens DONE
# epitopes NARROWER_TERM_FOR antigens DONE
# antibody formation RELATED_TERM antigens DONE
# immunization RELATED_TERM antigens DONE
# immunology RELATED_TERM antigens DONE
# antibodies RELATED_TERM antigens DONE
# lipopolysaccharides RELATED_TERM antigens DONE
# immune response RELATED_TERM antigens DONE
# antigen testing RELATED_TERM antigens DONE
#
# ---------------
#
# antigens RELATED_TERM antigen testing DONE
#
# ---------------
#
# drugs BROADER_TERM_FOR antiinfective agents DONE
# antibacterial agents NARROWER_TERM_FOR antiinfective agents DONE
# antifungal agents NARROWER_TERM_FOR antiinfective agents DONE
# antiviral agents NARROWER_TERM_FOR antiinfective agents DONE
# antimicrobial properties RELATED_TERM antiinfective agents DONE
# antiparasitic agents RELATED_TERM antiinfective agents DONE
# infections RELATED_TERM antiinfective agents DONE
# disinfection RELATED_TERM antiinfective agents DONE
# infectious diseases RELATED_TERM antiinfective agents DONE
# plant disease control RELATED_TERM antiinfective agents DONE
# antibiotics RELATED_TERM antiinfective agents DONE
#
# ---------------
#
# medicinal properties BROADER_TERM_FOR antiinflammatory properties DONE
# inflammation RELATED_TERM antiinflammatory properties DONE
# cytokines RELATED_TERM antiinflammatory properties DONE
#
# ---------------
#
# biological activity BROADER_TERM_FOR antimicrobial properties DONE
# antiviral properties NARROWER_TERM_FOR antimicrobial properties DONE
# antibacterial properties NARROWER_TERM_FOR antimicrobial properties DONE
# antifungal properties NARROWER_TERM_FOR antimicrobial properties DONE
# medicinal plants RELATED_TERM antimicrobial properties DONE
# antiinfective agents RELATED_TERM antimicrobial properties DONE
# medicinal properties RELATED_TERM antimicrobial properties DONE
# herbal drugs RELATED_TERM antimicrobial properties DONE
# toxicology RELATED_TERM antimicrobial properties DONE
#
# ---------------
#
# drugs BROADER_TERM_FOR antineoplastic agents DONE
# doxorubicin NARROWER_TERM_FOR antineoplastic agents DONE
# camptothecin NARROWER_TERM_FOR antineoplastic agents DONE
# anticancer properties RELATED_TERM antineoplastic agents DONE
# neoplasms RELATED_TERM antineoplastic agents DONE
# antineoplastic properties RELATED_TERM antineoplastic agents DONE
# cytotoxic compounds RELATED_TERM antineoplastic agents DONE
#
# ---------------
#
# anticancer properties BROADER_TERM_FOR antineoplastic properties DONE
# neoplasms RELATED_TERM antineoplastic properties DONE
# cytotoxicity RELATED_TERM antineoplastic properties DONE
# antineoplastic agents RELATED_TERM antineoplastic properties DONE
#
# ---------------
#
# oxygen RELATED_TERM antioxidants DONE
# oxidation RELATED_TERM antioxidants DONE
# feed additives RELATED_TERM antioxidants DONE
# chemistry RELATED_TERM antioxidants DONE
# phytochemicals RELATED_TERM antioxidants DONE
#
# ---------------
#
# physicochemical properties BROADER_TERM_FOR antioxidant properties DONE
#
# ---------------
#
# drugs BROADER_TERM_FOR antiparasitic agents DONE
# ectoparasiticides NARROWER_TERM_FOR antiparasitic agents DONE
# anthelmintics NARROWER_TERM_FOR antiparasitic agents DONE
# antiinfective agents RELATED_TERM antiparasitic agents DONE
# parasites RELATED_TERM antiparasitic agents DONE
#
# ---------------
#
# antiviral agents BROADER_TERM_FOR antiretroviral agents DONE
#
# ---------------
#
# antiinfective agents BROADER_TERM_FOR antiviral agents DONE
# ribavirin NARROWER_TERM_FOR antiviral agents DONE
# lysozyme NARROWER_TERM_FOR antiviral agents DONE
# interferons NARROWER_TERM_FOR antiviral agents DONE
# antiretroviral agents NARROWER_TERM_FOR antiviral agents DONE
# viruses RELATED_TERM antiviral agents DONE
# antiviral properties RELATED_TERM antiviral agents DONE
#
# ---------------
#
# antimicrobial properties BROADER_TERM_FOR antiviral properties DONE
# antiviral agents RELATED_TERM antiviral properties DONE
# viruses RELATED_TERM antiviral properties DONE
#
# ---------------
#
# emotions BROADER_TERM_FOR anxiety DONE
# mental stress RELATED_TERM anxiety DONE
#
# ---------------
#
#
# ---------------
#
# Hymenoptera BROADER_TERM_FOR Apidae DONE
# Melipona NARROWER_TERM_FOR Apidae DONE
# Apis NARROWER_TERM_FOR Apidae DONE
#
# ---------------
#
# Apidae BROADER_TERM_FOR Apis DONE
# Apis mellifera NARROWER_TERM_FOR Apis DONE
#
# ---------------
#
# Apis BROADER_TERM_FOR Apis mellifera DONE
# Apis mellifera capensis NARROWER_TERM_FOR Apis mellifera DONE
# Apis mellifera scutellata NARROWER_TERM_FOR Apis mellifera DONE
#
# ---------------
#
# Apis mellifera BROADER_TERM_FOR Apis mellifera capensis DONE
#
# ---------------
#
# Apis mellifera BROADER_TERM_FOR Apis mellifera scutellata DONE
#
# ---------------
#
#
# ---------------
#
#
# ---------------
#
#
# ---------------
#
# cell proliferation RELATED_TERM apoptosis DONE
# necrosis RELATED_TERM apoptosis DONE
#
# ---------------
#
# North Carolina NARROWER_TERM_FOR Appalachian States of USA DONE
# Virginia NARROWER_TERM_FOR Appalachian States of USA DONE
# Kentucky NARROWER_TERM_FOR Appalachian States of USA DONE
#
# ---------------
#
#
# ---------------
#
# apple pomace RELATED_TERM apples DONE
#
# ---------------
#
# apples RELATED_TERM apple pomace DONE
# Malus domestica RELATED_TERM apple pomace DONE
#
# ---------------
#
#
# ---------------
#
# application methods RELATED_TERM application date DONE
#
# ---------------
#
# controlled release NARROWER_TERM_FOR application methods DONE
# inoculation NARROWER_TERM_FOR application methods DONE
# foliar application NARROWER_TERM_FOR application methods DONE
# application date RELATED_TERM application methods DONE
#
# ---------------
#
# dosage effects RELATED_TERM application rates DONE
# technology RELATED_TERM application rates DONE
#
# ---------------
#
#
# ---------------
#
# livestock farming BROADER_TERM_FOR aquaculture DONE
# shellfish culture NARROWER_TERM_FOR aquaculture DONE
# aquaponics NARROWER_TERM_FOR aquaculture DONE
# marine aquaculture NARROWER_TERM_FOR aquaculture DONE
# fish culture NARROWER_TERM_FOR aquaculture DONE
# ancillary enterprises RELATED_TERM aquaculture DONE
# water RELATED_TERM aquaculture DONE
# aquarium fishes RELATED_TERM aquaculture DONE
# fisheries RELATED_TERM aquaculture DONE
#
# ---------------
#
# aquaculture BROADER_TERM_FOR aquaponics DONE
# hydroponics RELATED_TERM aquaponics DONE
#
# ---------------
#
#
# ---------------
#
# animal housing BROADER_TERM_FOR aquaria DONE
# aquarium fishes RELATED_TERM aquaria DONE
#
# ---------------
#
# aquaculture RELATED_TERM aquarium fishes DONE
# aquaria RELATED_TERM aquarium fishes DONE
#
# ---------------
#
# aquatic organisms BROADER_TERM_FOR aquatic animals DONE
# marine animals NARROWER_TERM_FOR aquatic animals DONE
# aquatic invertebrates NARROWER_TERM_FOR aquatic animals DONE
# marine ecology RELATED_TERM aquatic animals DONE
# Amphibia RELATED_TERM aquatic animals DONE
# freshwater ecology RELATED_TERM aquatic animals DONE
#
# ---------------
#
# communities BROADER_TERM_FOR aquatic communities DONE
# periphyton NARROWER_TERM_FOR aquatic communities DONE
# water RELATED_TERM aquatic communities DONE
# marine ecology RELATED_TERM aquatic communities DONE
# aquatic organisms RELATED_TERM aquatic communities DONE
# aquatic environment RELATED_TERM aquatic communities DONE
# freshwater ecology RELATED_TERM aquatic communities DONE
#
# ---------------
#
# environment BROADER_TERM_FOR aquatic environment DONE
# wetlands NARROWER_TERM_FOR aquatic environment DONE
# marine areas NARROWER_TERM_FOR aquatic environment DONE
# marine environment NARROWER_TERM_FOR aquatic environment DONE
# water RELATED_TERM aquatic environment DONE
# aquatic communities RELATED_TERM aquatic environment DONE
# aquatic organisms RELATED_TERM aquatic environment DONE
#
# ---------------
#
# aquatic animals BROADER_TERM_FOR aquatic invertebrates DONE
# shellfish NARROWER_TERM_FOR aquatic invertebrates DONE
#
# ---------------
#
# aquatic plants NARROWER_TERM_FOR aquatic organisms DONE
# plankton NARROWER_TERM_FOR aquatic organisms DONE
# aquatic animals NARROWER_TERM_FOR aquatic organisms DONE
# aquatic communities RELATED_TERM aquatic organisms DONE
# water RELATED_TERM aquatic organisms DONE
# marine ecology RELATED_TERM aquatic organisms DONE
# aquatic environment RELATED_TERM aquatic organisms DONE
# freshwater ecology RELATED_TERM aquatic organisms DONE
#
# ---------------
#
# aquatic organisms BROADER_TERM_FOR aquatic plants DONE
# marine plants NARROWER_TERM_FOR aquatic plants DONE
# marine ecology RELATED_TERM aquatic plants DONE
# algae RELATED_TERM aquatic plants DONE
# freshwater ecology RELATED_TERM aquatic plants DONE
#
# ---------------
#
# geology RELATED_TERM aquifers DONE
# hydrology RELATED_TERM aquifers DONE
#
# ---------------
#
#
# ---------------
#
# France BROADER_TERM_FOR Aquitaine DONE
#
# ---------------
#
# horses BROADER_TERM_FOR Arab DONE
#
# ---------------
#
#
# ---------------
#
# polyenoic fatty acids BROADER_TERM_FOR arachidonic acid DONE
#
# ---------------
#
#
# ---------------
#
#
# ---------------
#
# vector-borne diseases RELATED_TERM arboviruses DONE
# disease vectors RELATED_TERM arboviruses DONE
#
# ---------------
#
# endomycorrhizas BROADER_TERM_FOR arbuscular mycorrhizas DONE
#
# ---------------
#
# prokaryotes BROADER_TERM_FOR Archaea DONE
#
# ---------------
#
#
# ---------------
#
# Latin America BROADER_TERM_FOR Argentina DONE
#
# ---------------
#
#
# ---------------
#
#
# ---------------
#
# climate BROADER_TERM_FOR arid climate DONE
# arid lands RELATED_TERM arid climate DONE
# deserts RELATED_TERM arid climate DONE
# drought RELATED_TERM arid climate DONE
# arid zones RELATED_TERM arid climate DONE
#
# ---------------
#
# arid climate RELATED_TERM arid lands DONE
#
# ---------------
#
# arid climate RELATED_TERM arid zones DONE
# semiarid zones RELATED_TERM arid zones DONE
# xerophytes RELATED_TERM arid zones DONE
#
# ---------------
#
#
# ---------------
#
#
# ---------------
#
#
# ---------------
#
# flavour RELATED_TERM aroma DONE
#
# ---------------
#
# benzene NARROWER_TERM_FOR aromatic hydrocarbons DONE
# toluene NARROWER_TERM_FOR aromatic hydrocarbons DONE
# polycyclic aromatic hydrocarbons NARROWER_TERM_FOR aromatic hydrocarbons DONE
# essential oils RELATED_TERM aromatic hydrocarbons DONE
#
# ---------------
#
# Maranta arundinacea RELATED_TERM arrowroot DONE
#
# ---------------
#
#
# ---------------
#
# arsenicals RELATED_TERM arsenic DONE
#
# ---------------
#
# arsenites NARROWER_TERM_FOR arsenicals DONE
# arsenates NARROWER_TERM_FOR arsenicals DONE
# chemistry RELATED_TERM arsenicals DONE
# toxic substances RELATED_TERM arsenicals DONE
# arsenic RELATED_TERM arsenicals DONE
#
# ---------------
#
#
# ---------------
#
#
# ---------------
#
#
# ---------------
#
#
# ---------------
#
#
# ---------------
#
# Crustacea NARROWER_TERM_FOR arthropods DONE
# arthropod allergies RELATED_TERM arthropods DONE
#
# ---------------
#
# allergies BROADER_TERM_FOR arthropod allergies DONE
# arthropods RELATED_TERM arthropod allergies DONE
#
# ---------------
#
# pests BROADER_TERM_FOR arthropod pests DONE
# insect pests NARROWER_TERM_FOR arthropod pests DONE
#
# ---------------
#
# intrauterine insemination NARROWER_TERM_FOR artificial insemination DONE
# animal husbandry RELATED_TERM artificial insemination DONE
# semen preservation RELATED_TERM artificial insemination DONE
# semen diluent additives RELATED_TERM artificial insemination DONE
# semen RELATED_TERM artificial insemination DONE
# semen diluents RELATED_TERM artificial insemination DONE
#
# ---------------
#
# wetlands RELATED_TERM artificial wetlands DONE
# wastewater treatment RELATED_TERM artificial wetlands DONE
# waste treatment RELATED_TERM artificial wetlands DONE
#
# ---------------
#
# Artocarpus heterophyllus NARROWER_TERM_FOR Artocarpus DONE
# forest trees RELATED_TERM Artocarpus DONE
#
# ---------------
#
# Artocarpus BROADER_TERM_FOR Artocarpus heterophyllus DONE
#
# ---------------
#
# performing arts NARROWER_TERM_FOR arts DONE
# literature RELATED_TERM arts DONE
# handicrafts RELATED_TERM arts DONE
#
# ---------------
#
#
# ---------------
#
# fungi BROADER_TERM_FOR Ascomycota DONE
#
# ---------------
#
#
# ---------------
#
# South East Asia NARROWER_TERM_FOR Asia DONE
# East Asia NARROWER_TERM_FOR Asia DONE
# Central Asia NARROWER_TERM_FOR Asia DONE
#
# ---------------
#
# slope RELATED_TERM aspect DONE
# gradients RELATED_TERM aspect DONE
# topography RELATED_TERM aspect DONE
#
# ---------------
#
# Aspergillus niger NARROWER_TERM_FOR Aspergillus DONE
#
# ---------------
#
# Aspergillus BROADER_TERM_FOR Aspergillus niger DONE
#
# ---------------
#
# India BROADER_TERM_FOR Assam DONE
#
# ---------------
#
# estimation BROADER_TERM_FOR assessment DONE
# health impact assessment NARROWER_TERM_FOR assessment DONE
# risk assessment NARROWER_TERM_FOR assessment DONE
# taxes RELATED_TERM assessment DONE
#
# ---------------
#
# metabolism RELATED_TERM assimilation DONE
#
# ---------------
#
#
# ---------------
#
# respiratory diseases BROADER_TERM_FOR asthma DONE
#
# ---------------
#
#
# ---------------
#
# infections BROADER_TERM_FOR asymptomatic infections DONE
# subclinical mastitis RELATED_TERM asymptomatic infections DONE
#
# ---------------
#
#
# ---------------
#
# vascular diseases BROADER_TERM_FOR atherosclerosis DONE
#
# ---------------
#
#
# ---------------
#
# Salmo BROADER_TERM_FOR Atlantic salmon DONE
#
# ---------------
#
# environmental factors RELATED_TERM atmosphere DONE
# air RELATED_TERM atmosphere DONE
# meteorology RELATED_TERM atmosphere DONE
# meteorological factors RELATED_TERM atmosphere DONE
# climatic factors RELATED_TERM atmosphere DONE
#
# ---------------
#
# dermatitis BROADER_TERM_FOR atopic dermatitis DONE
#
# ...
# oil plants RELATED_TERM plant oils DONE
#
# ---------------
#
# parasites BROADER_TERM_FOR plant parasites DONE
# plant parasitic nematodes NARROWER_TERM_FOR plant parasites DONE
# host plants RELATED_TERM plant parasites DONE
# plant pathogens RELATED_TERM plant parasites DONE
#
# ---------------
#
# plant parasites BROADER_TERM_FOR plant parasitic nematodes DONE
# nematode control RELATED_TERM plant parasitic nematodes DONE
#
# ---------------
#
# plant pathogens BROADER_TERM_FOR plant pathogenic bacteria DONE
#
# ---------------
#
# plant pathogens BROADER_TERM_FOR plant pathogenic fungi DONE
# fungal diseases RELATED_TERM plant pathogenic fungi DONE
#
# ---------------
#
# pathogens BROADER_TERM_FOR plant pathogens DONE
# plant viruses NARROWER_TERM_FOR plant pathogens DONE
# plant pathogenic bacteria NARROWER_TERM_FOR plant pathogens DONE
# plant pathogenic fungi NARROWER_TERM_FOR plant pathogens DONE
# host plants RELATED_TERM plant pathogens DONE
# plant parasites RELATED_TERM plant pathogens DONE
# plant pests RELATED_TERM plant pathogens DONE
# plant diseases RELATED_TERM plant pathogens DONE
#
# ---------------
#
# pests BROADER_TERM_FOR plant pests DONE
# forest pests NARROWER_TERM_FOR plant pests DONE
# plant pathogens RELATED_TERM plant pests DONE
# birds RELATED_TERM plant pests DONE
#
# ---------------
#
# physiology BROADER_TERM_FOR plant physiology DONE
# phenology RELATED_TERM plant physiology DONE
# botany RELATED_TERM plant physiology DONE
# uptake RELATED_TERM plant physiology DONE
#
# ---------------
#
# flavonoids NARROWER_TERM_FOR plant pigments DONE
#
# ---------------
#
# plant oils NARROWER_TERM_FOR plant products DONE
# nuts NARROWER_TERM_FOR plant products DONE
# spices NARROWER_TERM_FOR plant products DONE
# straw NARROWER_TERM_FOR plant products DONE
# liquorice NARROWER_TERM_FOR plant products DONE
# fruit NARROWER_TERM_FOR plant products DONE
# lawns and turf NARROWER_TERM_FOR plant products DONE
# peel NARROWER_TERM_FOR plant products DONE
# cereal products NARROWER_TERM_FOR plant products DONE
# beans NARROWER_TERM_FOR plant products DONE
# grain NARROWER_TERM_FOR plant products DONE
# plant extracts NARROWER_TERM_FOR plant products DONE
# tobacco NARROWER_TERM_FOR plant products DONE
# cut flowers NARROWER_TERM_FOR plant products DONE
# sugar NARROWER_TERM_FOR plant products DONE
# beverages RELATED_TERM plant products DONE
# foods RELATED_TERM plant products DONE
# feeds RELATED_TERM plant products DONE
# dyes RELATED_TERM plant products DONE
# agricultural products RELATED_TERM plant products DONE
#
# ---------------
#
# health protection BROADER_TERM_FOR plant protection DONE
# disease control RELATED_TERM plant protection DONE
# weed control RELATED_TERM plant protection DONE
# disease prevention RELATED_TERM plant protection DONE
# cultural methods RELATED_TERM plant protection DONE
# pest control RELATED_TERM plant protection DONE
# protected cultivation RELATED_TERM plant protection DONE
# insect control RELATED_TERM plant protection DONE
# integrated control RELATED_TERM plant protection DONE
#
# ---------------
#
# proteins BROADER_TERM_FOR plant proteins DONE
# lectins NARROWER_TERM_FOR plant proteins DONE
#
# ---------------
#
# tissues BROADER_TERM_FOR plant tissues DONE
# mesophyll NARROWER_TERM_FOR plant tissues DONE
# meristems NARROWER_TERM_FOR plant tissues DONE
# periderm NARROWER_TERM_FOR plant tissues DONE
# bark NARROWER_TERM_FOR plant tissues DONE
# callus NARROWER_TERM_FOR plant tissues DONE
# vascular system NARROWER_TERM_FOR plant tissues DONE
# cells RELATED_TERM plant tissues DONE
# plant anatomy RELATED_TERM plant tissues DONE
# vascular bundles RELATED_TERM plant tissues DONE
# stomata RELATED_TERM plant tissues DONE
#
# ---------------
#
# plant pathogens BROADER_TERM_FOR plant viruses DONE
# plant diseases RELATED_TERM plant viruses DONE
#
# ---------------
#
# soil water RELATED_TERM plant water relations DONE
# flooding RELATED_TERM plant water relations DONE
# water stress RELATED_TERM plant water relations DONE
# irrigation RELATED_TERM plant water relations DONE
# water RELATED_TERM plant water relations DONE
# drought RELATED_TERM plant water relations DONE
# wilting RELATED_TERM plant water relations DONE
# water potential RELATED_TERM plant water relations DONE
# transpiration RELATED_TERM plant water relations DONE
# water use efficiency RELATED_TERM plant water relations DONE
# waterlogging RELATED_TERM plant water relations DONE
# evapotranspiration RELATED_TERM plant water relations DONE
# physiology RELATED_TERM plant water relations DONE
#
# ---------------
#
# spectroscopy BROADER_TERM_FOR plasma emission spectroscopy DONE
#
# ---------------
#
# cell membranes BROADER_TERM_FOR plasma membranes DONE
#
# ---------------
#
#
# ---------------
#
# Plasmodium vivax NARROWER_TERM_FOR Plasmodium DONE
#
# ---------------
#
# Plasmodium BROADER_TERM_FOR Plasmodium vivax DONE
#
# ---------------
#
#
# ---------------
#
# rheological properties BROADER_TERM_FOR plasticity DONE
#
# ---------------
#
# resins RELATED_TERM plastics DONE
# polyesters RELATED_TERM plastics DONE
# polyethylene RELATED_TERM plastics DONE
# waste plastic RELATED_TERM plastics DONE
# polypropylenes RELATED_TERM plastics DONE
# polymers RELATED_TERM plastics DONE
#
# ---------------
#
# amenity and recreation areas BROADER_TERM_FOR playgrounds DONE
#
# ---------------
#
# tillage BROADER_TERM_FOR ploughing DONE
#
# ---------------
#
# Ampelovirus BROADER_TERM_FOR Plum bark necrosis stem pitting-associated virus DONE
#
# ---------------
#
# respiratory diseases BROADER_TERM_FOR pneumonia DONE
#
# ---------------
#
# Urochloa NARROWER_TERM_FOR Poaceae DONE
# Cynodon NARROWER_TERM_FOR Poaceae DONE
# Triticum NARROWER_TERM_FOR Poaceae DONE
# Stipa NARROWER_TERM_FOR Poaceae DONE
# grasses RELATED_TERM Poaceae DONE
#
# ---------------
#
# sources BROADER_TERM_FOR point sources DONE
# light RELATED_TERM point sources DONE
#
# ---------------
#
# overdose NARROWER_TERM_FOR poisoning DONE
# toxicity RELATED_TERM poisoning DONE
# bioaccumulation RELATED_TERM poisoning DONE
# toxic gases RELATED_TERM poisoning DONE
# toxic substances RELATED_TERM poisoning DONE
# pollution RELATED_TERM poisoning DONE
#
# ---------------
#
# Central Europe BROADER_TERM_FOR Poland DONE
#
# ---------------
#
# Luteoviridae BROADER_TERM_FOR Polerovirus DONE
# Cucurbit aphid-borne yellows virus NARROWER_TERM_FOR Polerovirus DONE
#
# ---------------
#
# roundwood BROADER_TERM_FOR poles DONE
#
# ---------------
#
# food policy NARROWER_TERM_FOR policy DONE
# trade policy NARROWER_TERM_FOR policy DONE
# tourism policy NARROWER_TERM_FOR policy DONE
# environmental policy NARROWER_TERM_FOR policy DONE
# development policy NARROWER_TERM_FOR policy DONE
# forest policy NARROWER_TERM_FOR policy DONE
# agricultural policy NARROWER_TERM_FOR policy DONE
# monetary policy NARROWER_TERM_FOR policy DONE
# water policy NARROWER_TERM_FOR policy DONE
# fishery policy NARROWER_TERM_FOR policy DONE
# government policy NARROWER_TERM_FOR policy DONE
# health policy NARROWER_TERM_FOR policy DONE
# nutrition policy NARROWER_TERM_FOR policy DONE
# economic policy NARROWER_TERM_FOR policy DONE
# sport policy NARROWER_TERM_FOR policy DONE
# social sciences RELATED_TERM policy DONE
#
# ---------------
#
# politics RELATED_TERM political power DONE
# leadership RELATED_TERM political power DONE
#
# ---------------
#
# political power RELATED_TERM politics DONE
# social sciences RELATED_TERM politics DONE
#
# ---------------
#
# gametes BROADER_TERM_FOR pollen DONE
# pollinators RELATED_TERM pollen DONE
# pollination RELATED_TERM pollen DONE
# gametogenesis RELATED_TERM pollen DONE
#
# ---------------
#
# reproduction BROADER_TERM_FOR pollination DONE
# fertilization RELATED_TERM pollination DONE
# flowers RELATED_TERM pollination DONE
# pollinators RELATED_TERM pollination DONE
# fruiting RELATED_TERM pollination DONE
# pollen RELATED_TERM pollination DONE
#
# ---------------
#
# pollination RELATED_TERM pollinators DONE
# pollen RELATED_TERM pollinators DONE
# insects RELATED_TERM pollinators DONE
# honey bees RELATED_TERM pollinators DONE
#
# ---------------
#
# air pollutants NARROWER_TERM_FOR pollutants DONE
# toxic substances RELATED_TERM pollutants DONE
# contaminants RELATED_TERM pollutants DONE
# sulfur dioxide RELATED_TERM pollutants DONE
# pollution RELATED_TERM pollutants DONE
# oil spills RELATED_TERM pollutants DONE
#
# ---------------
#
# sediment BROADER_TERM_FOR polluted sediment DONE
# pollution RELATED_TERM polluted sediment DONE
#
# ---------------
#
# pollution RELATED_TERM polluted soils DONE
#
# ---------------
#
# water BROADER_TERM_FOR polluted water DONE
# water treatment RELATED_TERM polluted water DONE
# water pollution RELATED_TERM polluted water DONE
#
# ---------------
#
# air pollution NARROWER_TERM_FOR pollution DONE
# water pollution NARROWER_TERM_FOR pollution DONE
# soil pollution NARROWER_TERM_FOR pollution DONE
# oil spills NARROWER_TERM_FOR pollution DONE
# environmental impact RELATED_TERM pollution DONE
# toxic substances RELATED_TERM pollution DONE
# wastes RELATED_TERM pollution DONE
# polluted sediment RELATED_TERM pollution DONE
# air pollutants RELATED_TERM pollution DONE
# environmental policy RELATED_TERM pollution DONE
# pollutants RELATED_TERM pollution DONE
# polluted soils RELATED_TERM pollution DONE
# nontarget effects RELATED_TERM pollution DONE
# contamination RELATED_TERM pollution DONE
# pollution control RELATED_TERM pollution DONE
# chemical oxygen demand RELATED_TERM pollution DONE
# wastewater RELATED_TERM pollution DONE
# poisoning RELATED_TERM pollution DONE
# effluents RELATED_TERM pollution DONE
#
# ---------------
#
# environmental protection BROADER_TERM_FOR pollution control DONE
# recycling RELATED_TERM pollution control DONE
# pollution RELATED_TERM pollution control DONE
# waste treatment RELATED_TERM pollution control DONE
# nature conservation RELATED_TERM pollution control DONE
#
# ---------------
#
# contaminants RELATED_TERM polychlorinated biphenyls DONE
#
# ---------------
#
# aromatic hydrocarbons BROADER_TERM_FOR polycyclic aromatic hydrocarbons DONE
# phenanthrene NARROWER_TERM_FOR polycyclic aromatic hydrocarbons DONE
#
# ---------------
#
# hydrocarbons BROADER_TERM_FOR polycyclic hydrocarbons DONE
#
# ---------------
#
# arachidonic acid NARROWER_TERM_FOR polyenoic fatty acids DONE
#
# ---------------
#
# plastics RELATED_TERM polyesters DONE
#
# ---------------
#
# polymers BROADER_TERM_FOR polyethylene DONE
# plastics RELATED_TERM polyethylene DONE
#
# ---------------
#
# reverse transcriptase PCR NARROWER_TERM_FOR polymerase chain reaction DONE
# real time PCR NARROWER_TERM_FOR polymerase chain reaction DONE
# amplified fragment length polymorphism RELATED_TERM polymerase chain reaction DONE
#
# ---------------
#
# lignin NARROWER_TERM_FOR polymers DONE
# polyesters NARROWER_TERM_FOR polymers DONE
# polyethylene NARROWER_TERM_FOR polymers DONE
# polypropylenes NARROWER_TERM_FOR polymers DONE
# resins RELATED_TERM polymers DONE
# chemistry RELATED_TERM polymers DONE
# polysaccharides RELATED_TERM polymers DONE
# plastics RELATED_TERM polymers DONE
#
# ---------------
#
# peptides BROADER_TERM_FOR polypeptides DONE
# transforming growth factor NARROWER_TERM_FOR polypeptides DONE
# insulin NARROWER_TERM_FOR polypeptides DONE
#
# ---------------
#
# phenols BROADER_TERM_FOR polyphenols DONE
# lignin RELATED_TERM polyphenols DONE
#
# ---------------
#
# polymers BROADER_TERM_FOR polypropylenes DONE
# plastics RELATED_TERM polypropylenes DONE
#
# ---------------
#
# carbohydrates BROADER_TERM_FOR polysaccharides DONE
# glucans NARROWER_TERM_FOR polysaccharides DONE
# mannans NARROWER_TERM_FOR polysaccharides DONE
# lipopolysaccharides NARROWER_TERM_FOR polysaccharides DONE
# polymers RELATED_TERM polysaccharides DONE
#
# ---------------
#
# Pomacea canaliculata NARROWER_TERM_FOR Pomacea DONE
#
# ---------------
#
# Pomacea BROADER_TERM_FOR Pomacea canaliculata DONE
#
# ---------------
#
#
# ---------------
#
# hydrographic structures BROADER_TERM_FOR ponds DONE
# reservoirs RELATED_TERM ponds DONE
#
# ---------------
#
# trees BROADER_TERM_FOR poplars DONE
# Populus RELATED_TERM poplars DONE
#
# ---------------
#
# contraception RELATED_TERM population control DONE
#
# ---------------
#
#
# ---------------
#
#
# ---------------
#
# ecology BROADER_TERM_FOR population ecology DONE
#
# ---------------
#
# genetics BROADER_TERM_FOR population genetics DONE
#
# ---------------
#
# structure BROADER_TERM_FOR population structure DONE
# age differences RELATED_TERM population structure DONE
# families RELATED_TERM population structure DONE
#
# ---------------
#
#
# ---------------
#
# Populus deltoides NARROWER_TERM_FOR Populus DONE
# Populus tremula NARROWER_TERM_FOR Populus DONE
# poplars RELATED_TERM Populus DONE
#
# ---------------
#
# Populus BROADER_TERM_FOR Populus deltoides DONE
#
# ---------------
#
# Populus BROADER_TERM_FOR Populus tremula DONE
#
# ---------------
#
#
# ---------------
#
# Circovirus BROADER_TERM_FOR Porcine circovirus 2 DONE
#
# ---------------
#
# Circovirus BROADER_TERM_FOR Porcine circovirus 3 DONE
#
# ---------------
#
# swine diseases BROADER_TERM_FOR porcine reproductive and respiratory syndrome DONE
#
# ---------------
#
# physical properties BROADER_TERM_FOR porosity DONE
# permeability RELATED_TERM porosity DONE
#
# ---------------
#
#
# ---------------
#
# Madeira NARROWER_TERM_FOR Portugal DONE
#
# ---------------
#
# mental disorders BROADER_TERM_FOR post-traumatic stress disorder DONE
# mental stress RELATED_TERM post-traumatic stress disorder DONE
#
# ---------------
#
# treatment RELATED_TERM postharvest treatment DONE
#
# ---------------
#
#
# ---------------
#
# patient care BROADER_TERM_FOR postoperative care DONE
# surgical operations RELATED_TERM postoperative care DONE
#
# ---------------
#
# surgical operations RELATED_TERM postoperative complications DONE
#
# ---------------
#
# behaviour RELATED_TERM posture DONE
#
# ---------------
#
# infants RELATED_TERM postweaning interval DONE
# biological development RELATED_TERM postweaning interval DONE
#
# ---------------
#
#
# ---------------
#
#
# ---------------
#
# characteristics BROADER_TERM_FOR potency DONE
#
# ---------------
#
# Alphaflexiviridae BROADER_TERM_FOR Potexvirus DONE
# Cassava common mosaic virus NARROWER_TERM_FOR Potexvirus DONE
#
# ---------------
#
# Potyvirus NARROWER_TERM_FOR Potyviridae DONE
#
# ---------------
#
# Potyviridae BROADER_TERM_FOR Potyvirus DONE
# Bean common mosaic virus NARROWER_TERM_FOR Potyvirus DONE
#
# ---------------
#
# ornamental plants BROADER_TERM_FOR pot plants DONE
#
# ---------------
#
# domestic animals BROADER_TERM_FOR poultry DONE
# broilers NARROWER_TERM_FOR poultry DONE
# poultry manure RELATED_TERM poultry DONE
# laying performance RELATED_TERM poultry DONE
#
# ---------------
#
# livestock farming BROADER_TERM_FOR poultry farming DONE
# hen feeding RELATED_TERM poultry farming DONE
#
# ---------------
#
# animal feeding BROADER_TERM_FOR poultry feeding DONE
# fowl feeding NARROWER_TERM_FOR poultry feeding DONE
#
# ---------------
#
# animal manures BROADER_TERM_FOR poultry manure DONE
# poultry RELATED_TERM poultry manure DONE
#
# ---------------
#
# chicken meat NARROWER_TERM_FOR poultry meat DONE
#
# ---------------
#
# economics RELATED_TERM poverty DONE
# Food Stamp Program RELATED_TERM poverty DONE
# low income groups RELATED_TERM poverty DONE
# poverty alleviation RELATED_TERM poverty DONE
# hunger RELATED_TERM poverty DONE
#
# ---------------
#
# poverty RELATED_TERM poverty alleviation DONE
#
# ---------------
#
#
# ---------------
#
#
# ---------------
#
# shrimps RELATED_TERM prawns DONE
#
# ---------------
#
# prophylaxis BROADER_TERM_FOR pre-exposure prophylaxis DONE
#
# ---------------
#
# supplements BROADER_TERM_FOR prebiotics DONE
# probiotics RELATED_TERM prebiotics DONE
# oligosaccharides RELATED_TERM prebiotics DONE
# functional foods RELATED_TERM prebiotics DONE
# ingredients RELATED_TERM prebiotics DONE
# intestinal microorganisms RELATED_TERM prebiotics DONE
#
# ---------------
#
# snow NARROWER_TERM_FOR precipitation DONE
# rain NARROWER_TERM_FOR precipitation DONE
# watershed management RELATED_TERM precipitation DONE
# meteorology RELATED_TERM precipitation DONE
# wet season RELATED_TERM precipitation DONE
# climatology RELATED_TERM precipitation DONE
# watersheds RELATED_TERM precipitation DONE
#
# ---------------
#
# computer techniques RELATED_TERM precision agriculture DONE
# global positioning systems RELATED_TERM precision agriculture DONE
# geographical information systems RELATED_TERM precision agriculture DONE
#
# ---------------
#
# feeding habits BROADER_TERM_FOR predation DONE
# predators RELATED_TERM predation DONE
# biological control RELATED_TERM predation DONE
#
# ---------------
#
# predatory arthropods NARROWER_TERM_FOR predators DONE

# %%
# driver = GraphDatabase.driver(neo4j_url, auth=(neo4j_username, neo4j_password))    
# with driver.session(database=neo4j_database) as session:
#     all_articles_nodes = session.execute_read(get_nodes,'article')
#     all_concept_nodes = session.execute_read(get_nodes,'concept')

# %%
# # Creating a mapping of concept names to nodes for efficient lookup
# concept_name_to_node = {node['n'].get('name'): node['n'] for node in all_concept_nodes if node['n'].get('name')}


# with driver.session(database=neo4j_database) as session:

#     # Mapping of vocab type to relationship name
#     vocab_type_to_relationship_name = {
#         'preferred_terms': 'HAS_PREFERRED_TERM',
#         'organism_terms': 'HAS_ORGANISM_TERM',
#         'geographic_terms': 'HAS_GEOGRAPHIC_TERM',
#     }
    
#     # Step 2: Create Article to Concept relationships
#     for article_node in all_articles_nodes:
#         article_node= article_node['n']
#         article_content = article_node['info']
        
#         vocab_sections = extract_vocab_sections_from_article_content(article_content)
       
#         for vocab_type, concepts in vocab_sections.items():
#             relationship_name = vocab_type_to_relationship_name.get(vocab_type)
#             for concept_name in concepts:
#                 concept_node = concept_name_to_node.get(concept_name)
#                 if concept_node and relationship_name:                    
#                     try:
#                         session.execute_write(create_article_concept_relationship, article_node, concept_node, relationship_name)
#                         print(article_node['pan'], relationship_name, concept_node['name'], 'DONE')                        
#                     except:
#                         print(article_node['pan'], relationship_name, concept_node['name'], 'ERROR')        
#         # if article_node['n']['pan']=='20203180098':
#         #     break
    
#         print()
#         print('---------------')
#         print()


#     # Step 3: Create Concept to Concept relationships
#     for concept_node in all_concept_nodes:
#         concept_details = concept_node['n']['info']  # Adjust field name based on your data structure
#         print(concept_node['n']['name'])
        
#         # Identify broader, narrower, and related concepts using regex
#         broader_concept_section = re.search(r'Broader Concept:\s*\n*\s*name: (.*?)(?:\n|, uri)', concept_details)
#         if broader_concept_section:
#             broader_concepts = [broader_concept_section.group(1)]
#         else:
#             broader_concepts = []
        
#         narrower_concept_section = re.search(r'Narrower Concepts:([\s\S]*?)(?:Broader Concepts:|Related Concepts:|$)', concept_details)
#         if narrower_concept_section:
#             narrower_concepts = re.findall(r'name: (.*?)(?:, uri|\n|$)', narrower_concept_section.group(1))
#         else:
#             narrower_concepts = []
        
#         related_concept_section = re.search(r'Related Concepts:([\s\S]*?)(?:Broader Concepts:|Narrower Concepts:|$)', concept_details)
#         if related_concept_section:
#             related_concepts = re.findall(r'name: (.*?)(?:, uri|\n|$)', related_concept_section.group(1))
#         else:
#             related_concepts = []
    
#         # if concept_node['n']['name']=='Ebolavirus':
#         #     break
        
#         # Create relationships with other concept nodes based on broader, narrower, and related concepts
#         for broader_concept_name in broader_concepts:
#             broader_concept_node = concept_name_to_node.get(broader_concept_name)
#             if broader_concept_node:
#                 try:
#                     session.execute_write(create_concept_relationship, broader_concept_node, concept_node, 'BROADER_TERM_FOR')
#                     print(broader_concept_node['name'], 'BROADER_TERM_FOR', concept_node['n']['name'], 'DONE')                    
#                 except:
#                     print(broader_concept_node['name'], 'BROADER_TERM_FOR', concept_node['n']['name'], 'ERROR')  
    
#         for narrower_concept_name in narrower_concepts:
#             narrower_concept_node = concept_name_to_node.get(narrower_concept_name)
#             if narrower_concept_node:
#                 try:
#                     session.execute_write(create_concept_relationship, narrower_concept_node, concept_node, 'NARROWER_TERM_FOR')
#                     print(narrower_concept_node['name'], 'NARROWER_TERM_FOR', concept_node['n']['name'], 'DONE')                    
#                 except:
#                     print(narrower_concept_node['name'], 'NARROWER_TERM_FOR', concept_node['n']['name'], 'ERROR')
    
#         for related_concept_name in related_concepts:
#             related_concept_node = concept_name_to_node.get(related_concept_name)
#             if related_concept_node:
#                 try:
#                     session.execute_write(create_concept_relationship, related_concept_node, concept_node, 'RELATED_TERM')
#                     print(related_concept_node['name'], 'RELATED_TERM', concept_node['n']['name'], 'DONE')                    
#                 except:
#                     print(related_concept_node['name'], 'RELATED_TERM', concept_node['n']['name'], 'ERROR')
    
#         print()
#         print('---------------')
#         print()
